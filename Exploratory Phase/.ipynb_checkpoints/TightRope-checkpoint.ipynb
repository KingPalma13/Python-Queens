# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
from scipy import stats
from scipy.stats import boxcox
from statsmodels.stats.proportion import proportions_ztest

# %%
AirbnbRentals = pd.read_csv("C:/Users/vanch/Desktop/Entity/DSO110/Exploratory Phase/AirbnbRentals.csv")

# %%
AirbnbRentals.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0                  *UT/Hyde Park Craftsman Apartment
# 1           1   Zen-East in the Heart of Austin (monthly rental)
# 2           2  Eco friendly, Colorful, Clean, Cozy monthly share
# 3           3          Walk to 6th, Rainey St and Convention Ctr
# 4           4                                     NW Austin Room
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0         78705  30.30002  -97.73637  Entire home/apt    102               1
# 1         78702  30.27752  -97.71377  Entire home/apt    179               7
# 2         78702  30.27614  -97.71320     Private room    114              30
# 3         78702  30.26057  -97.73441  Entire home/apt    104               2
# 4         78729  30.45697  -97.78422     Private room     39               1
#
#    number_of_reviews  availability_365  room
# 0                232                 0     0
# ...

# %%
AirbnbRentals.drop(AirbnbRentals.columns[AirbnbRentals.columns.str.contains('unnamed',case = False)],
                   axis=1, inplace = True)

# %%
AirbnbRentals.head()
# Out:
#                                                 name neighbourhood  latitude  \
# 0                  *UT/Hyde Park Craftsman Apartment         78705  30.30002
# 1   Zen-East in the Heart of Austin (monthly rental)         78702  30.27752
# 2  Eco friendly, Colorful, Clean, Cozy monthly share         78702  30.27614
# 3          Walk to 6th, Rainey St and Convention Ctr         78702  30.26057
# 4                                     NW Austin Room         78729  30.45697
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -97.73637  Entire home/apt    102               1                232
# 1  -97.71377  Entire home/apt    179               7                 26
# 2  -97.71320     Private room    114              30                  9
# 3  -97.73441  Entire home/apt    104               2                578
# 4  -97.78422     Private room     39               1                264
#
#    availability_365  room
# 0                 0     0
# ...

# %%
#Getting means for columns with normal

# %%
cols = ['price', 'minimum_nights', 'number_of_reviews', 'availability_365']

AirbnbRentals[cols].mean()
# Out:
# price                237.743009
# minimum_nights        15.954118
# number_of_reviews     41.706494
# availability_365     175.901665
# dtype: float64

# %%
AirbnbRentals.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  64687.000000  64687.000000  64687.000000    64687.000000
# mean      35.480707   -106.304214    237.743009       15.954118
# std        4.276836     15.478247    579.841057       30.750504
# min       30.078870   -122.832860      0.000000        1.000000
# 25%       33.959120   -118.377695     81.000000        2.000000
# 50%       34.088040   -118.145410    130.000000        3.000000
# 75%       36.169460    -87.785840    224.000000       30.000000
# max       45.612050    -70.997810  25000.000000     1124.000000
#
#        number_of_reviews  availability_365          room
# count       64687.000000      64687.000000  64687.000000
# mean           41.706494        175.901665      0.291357
# std            78.973987        138.957099      0.514962
# min             0.000000          0.000000      0.000000
# 25%             1.000000         36.000000      0.000000
# ...

# %%
AirbnbRentals.shape
# Out:
# (64687, 10)

# %%
#Exploring year round availability

# %%
sns.pairplot(AirbnbRentals)
